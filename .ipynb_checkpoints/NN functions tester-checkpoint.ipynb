# %%
from pydst.nn_utils import tfgraph
import tensorflow as tf


from IPython.display import display, HTML
import datetime

def show_graph(graph_def, frame_size=(900, 600)):
    """Visualize TensorFlow graph."""
    if hasattr(graph_def, 'as_graph_def'):
        graph_def = graph_def.as_graph_def()
    timestamp = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
    code = """
        <script>
          function load() {{
            document.getElementById("{id}").pbtxt = {data};
          }}
        </script>
        <link rel="import" href="https://tensorboard.appspot.com/tf-graph-basic.build.html" onload=load()>
        <div style="height:{height}px">
          <tf-graph-basic id="{id}"></tf-graph-basic>
        </div>
    """.format(height=frame_size[1], data=repr(str(graph_def)), id='graph'+timestamp)
    iframe = """
        <iframe seamless style="width:{width}px;height:{height}px;border:0" srcdoc="{src}"></iframe>
    """.format(width=frame_size[0], height=frame_size[1] + 20, src=code.replace('"', '&quot;'))
    display(HTML(iframe))

# %%
graph = tf.Graph()
with graph.as_default():
    inputs = tf.placeholder(tf.float32, [None, 128], 'inputs')
    targets = tf.placeholder(tf.float32, [None, 10], 'targets')
    
graph1 = tfgraph(graph, inputs, targets, 'inputs', 'targets')
graph1.add_ffl(units=100, name='1-layer', activation=tf.nn.relu)
graph1.add_ffl(units=70, name='2-layer', activation=tf.nn.relu)
graph1.add_ffl(units=50, name='3-layer', activation=tf.nn.relu)
graph1.add_ffl(units=10, name='4-layer', activation=None)
graph1.error_softmax(output_layer_name='4-layer', name='error-4l')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-2603f703d868> in <module>()
#       8 graph1.add_ffl(units=70, name='2-layer', activation=tf.nn.relu)
#       9 graph1.add_ffl(units=50, name='3-layer', activation=tf.nn.relu)
# ---> 10 graph1.add_ffl(units=10, name='4-layer', activation=tf.nn.identity)
#      11 graph1.error_softmax(output_layer_name='4-layer', name='error-4l')
#
# AttributeError: 'module' object has no attribute 'identity'

# %%
show_graph(graph)
# Out:
#         <iframe seamless style="width:900px;height:620px;border:0" srcdoc="
#         <script>
#           function load() {
#             document.getElementById(&quot;graph2017-06-07_14-16-30&quot;).pbtxt = 'node {\n  name: &quot;inputs&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;targets&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;first-layer/kernel/Initializer/random_uniform/shape&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@first-layer/kernel&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 2\n          }\n        }\n        tensor_content: &quot;\\200\\000\\000\\000d\\000\\000\\000&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;first-layer/kernel/Initializer/random_uniform/min&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@first-layer/kernel&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: -0.162221416831\n      }\n    }\n  }\n}\nnode {\n  name: &quot;first-layer/kernel/Initializer/random_uniform/max&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@first-layer/kernel&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.162221416831\n      }\n    }\n  }\n}\nnode {\n  name: &quot;first-layer/kernel/Initializer/random_uniform/RandomUniform&quot;\n  op: &quot;RandomUniform&quot;\n  input: &quot;first-layer/kernel/Initializer/random_uniform/shape&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@first-layer/kernel&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;seed&quot;\n    value {\n      i: 0\n    }\n  }\n  attr {\n    key: &quot;seed2&quot;\n    value {\n      i: 0\n    }\n  }\n}\nnode {\n  name: &quot;first-layer/kernel/Initializer/random_uniform/sub&quot;\n  op: &quot;Sub&quot;\n  input: &quot;first-layer/kernel/Initializer/random_uniform/max&quot;\n  input: &quot;first-layer/kernel/Initializer/random_uniform/min&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@first-layer/kernel&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;first-layer/kernel/Initializer/random_uniform/mul&quot;\n  op: &quot;Mul&quot;\n  input: &quot;first-layer/kernel/Initializer/random_uniform/RandomUniform&quot;\n  input: &quot;first-layer/kernel/Initializer/random_uniform/sub&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@first-layer/kernel&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;first-layer/kernel/Initializer/random_uniform&quot;\n  op: &quot;Add&quot;\n  input: &quot;first-layer/kernel/Initializer/random_uniform/mul&quot;\n  input: &quot;first-layer/kernel/Initializer/rand ...
